# %% [markdown]
# # Reference implementation of Deep Q-Learning
#
# This notebook includes an implementation of the Deep Q-learning algorithm for the Cartpole problem (see [Cartpole documentation](https://gymnasium.farama.org/environments/classic_control/cart_pole/)).

# %% [markdown]
# ## Libraries

# %%
# !pip install gymnasium[classic-control]
# !pip install "gymnasium[box2d]"
import gymnasium as gym
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import time
import random
import math

# Reproducibilidad (opcional, pero ayuda a depurar)
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium[classic-control] in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[classic-control]) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[classic-control]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[classic-control]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[classic-control]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[classic-control]) (2.6.1)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\motac\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium[box2d] in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d==2.3.10 in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[box2d]) (2.3.10)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in c:\users\motac\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gymnasium[box2d]) (4.4.1)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\motac\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Hyperparameters

# %%
# Learning rate (más estable para LunarLander)
LEARNING_RATE = 2.5e-4

# Batch size
BATCH_SIZE = 128

# Discount factor gamma
GAMMA = 0.99

# Size of the replay memory (replay buffer)
MEMORY_SIZE = 200_000

# Warm-up: pasos mínimos antes de empezar a entrenar
WARMUP_STEPS = 10_000

# Entrenar cada N pasos de interacción (1 = cada paso)
TRAIN_EVERY = 4

# Exploración epsilon-greedy por PASOS (no por episodio)
EPSILON_START = 1.0
EPSILON_END = 0.02
EPSILON_DECAY_STEPS = 150_000  # lineal hasta EPSILON_END

# Target network (soft update / Polyak)
TAU = 0.005

# Máximo número de episodios de entrenamiento (se para antes si alcanza el objetivo)
MAX_EPISODES_FOR_TRAINING = 2000

# Goal score a alcanzar durante entrenamiento (media de últimos episodios)
TRAINING_GOAL = 200

# Número de episodios usados para comprobar el objetivo durante entrenamiento
EPISODES_TO_CHECK_TRAINING_GOAL = 50

# Número de episodios para evaluar al final
EPISODES_TO_EVALUATE_MODEL_PERFORMANCE = 30

# %% [markdown]
# ## Class ReplayMemory
#
# Memory of transitions for experience replay.

# %%
class ReplayMemory:

    def __init__(self, number_of_observations):
        # Replay buffer circular (ring buffer)
        self.states = np.zeros((MEMORY_SIZE, number_of_observations), dtype=np.float32)
        self.states_next = np.zeros((MEMORY_SIZE, number_of_observations), dtype=np.float32)
        self.actions = np.zeros(MEMORY_SIZE, dtype=np.int32)
        self.rewards = np.zeros(MEMORY_SIZE, dtype=np.float32)
        self.dones = np.zeros(MEMORY_SIZE, dtype=np.float32)  # 1.0 si done, 0.0 si no

        self.position = 0
        self.current_size = 0

    def store_transition(self, state, action, reward, state_next, done):
        self.states[self.position] = state
        self.states_next[self.position] = state_next
        self.actions[self.position] = action
        self.rewards[self.position] = reward
        self.dones[self.position] = 1.0 if done else 0.0

        self.position = (self.position + 1) % MEMORY_SIZE
        self.current_size = min(self.current_size + 1, MEMORY_SIZE)

    def sample_memory(self, batch_size):
        batch = np.random.choice(self.current_size, batch_size, replace=False)
        states = self.states[batch]
        states_next = self.states_next[batch]
        rewards = self.rewards[batch]
        actions = self.actions[batch]
        dones = self.dones[batch]
        return states, actions, rewards, states_next, dones

# %% [markdown]
# ## Class DQN
#
# Reinforcement learning agent with a Deep Q-Network.

# %%
class RunningMeanStd:
    def __init__(self, shape, eps=1e-4):
        self.mean = np.zeros(shape, dtype=np.float32)
        self.var = np.ones(shape, dtype=np.float32)
        self.count = eps

    def update(self, x):
        x = np.asarray(x, dtype=np.float32)
        batch_mean = x.mean(axis=0)
        batch_var = x.var(axis=0)
        batch_count = x.shape[0] if x.ndim > 1 else 1

        delta = batch_mean - self.mean
        tot_count = self.count + batch_count
        new_mean = self.mean + delta * batch_count / tot_count

        m_a = self.var * self.count
        m_b = batch_var * batch_count
        M2 = m_a + m_b + (delta**2) * self.count * batch_count / tot_count
        new_var = M2 / tot_count

        self.mean, self.var, self.count = new_mean, new_var, tot_count

    def normalize(self, x):
        return (x - self.mean) / (np.sqrt(self.var) + 1e-8)

# %%
class DQN:
    def __init__(self, number_of_observations, number_of_actions):
        self.number_of_actions = int(number_of_actions)
        self.number_of_observations = int(number_of_observations)

        self.scores = []
        self.memory = ReplayMemory(self.number_of_observations)

        # Normalización online de observaciones
        self.obs_rms = RunningMeanStd(self.number_of_observations)

        # Online network (Dueling DQN)
        self.model = self._build_dueling_network()

        # Target network
        self.target_model = self._build_dueling_network()
        self.target_model.set_weights(self.model.get_weights())

        # Optimización estable
        self.optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE, clipnorm=10.0)
        self.loss_fn = keras.losses.Huber()

    def _build_dueling_network(self):
        inputs = keras.layers.Input(shape=(self.number_of_observations,), dtype=tf.float32)

        x = keras.layers.Dense(256, activation="relu", kernel_initializer="he_normal")(inputs)
        x = keras.layers.Dense(256, activation="relu", kernel_initializer="he_normal")(x)

        # Value stream V(s)
        v = keras.layers.Dense(128, activation="relu", kernel_initializer="he_normal")(x)
        v = keras.layers.Dense(1, activation="linear")(v)

        # Advantage stream A(s,a)
        a = keras.layers.Dense(128, activation="relu", kernel_initializer="he_normal")(x)
        a = keras.layers.Dense(self.number_of_actions, activation="linear")(a)

        # Mean advantage
        a_mean = keras.layers.Lambda(
            lambda t: tf.reduce_mean(t, axis=1, keepdims=True),
            output_shape=(1,)
        )(a)

        # Q(s,a) = V(s) + (A(s,a) - mean(A))
        q = v + (a - a_mean)

        return keras.Model(inputs=inputs, outputs=q)

    def remember(self, state, action, reward, next_state, done):
        # done debe ser "terminal real" (terminated), no truncated
        state = np.asarray(state, dtype=np.float32)
        next_state = np.asarray(next_state, dtype=np.float32)

        self.memory.store_transition(state, action, reward, next_state, done)

        # actualiza normalizador con estados reales observados
        self.obs_rms.update(state)
        self.obs_rms.update(next_state)

    def _prep_state(self, state):
        s = self.obs_rms.normalize(np.asarray(state, dtype=np.float32))
        s = np.clip(s, -5, 5)
        return s

    def select(self, state, exploration_rate):
        # epsilon-greedy
        if np.random.rand() < exploration_rate:
            return random.randrange(self.number_of_actions)

        s = self._prep_state(state)[None, :]  # (1, obs)
        q_values = self.model(s, training=False).numpy()[0]
        return int(np.argmax(q_values))

    def select_greedy_policy(self, state):
        s = self._prep_state(state)[None, :]  # (1, obs)
        q_values = self.model(s, training=False).numpy()[0]
        return int(np.argmax(q_values))

    def _soft_update_target(self):
        for target_var, var in zip(self.target_model.trainable_variables, self.model.trainable_variables):
            target_var.assign((1.0 - TAU) * target_var + TAU * var)

    def learn(self):
        # No entrenes hasta tener suficiente buffer
        if self.memory.current_size < BATCH_SIZE:
            return

        states, actions, rewards, next_states, dones = self.memory.sample_memory(BATCH_SIZE)

        # Normaliza states y next_states
        states = np.clip(self.obs_rms.normalize(states), -5, 5).astype(np.float32)
        next_states = np.clip(self.obs_rms.normalize(next_states), -5, 5).astype(np.float32)

        # Tensores
        states_t = tf.convert_to_tensor(states, dtype=tf.float32)
        next_states_t = tf.convert_to_tensor(next_states, dtype=tf.float32)
        actions_t = tf.convert_to_tensor(actions, dtype=tf.int32)
        rewards_t = tf.convert_to_tensor(rewards, dtype=tf.float32)
        dones_t = tf.convert_to_tensor(dones, dtype=tf.float32)

        # Double DQN target:
        # a* = argmax_a Q_online(s', a)
        next_q_online = self.model(next_states_t, training=False)
        next_actions = tf.argmax(next_q_online, axis=1, output_type=tf.int32)

        # Q_target(s', a*)
        next_q_target = self.target_model(next_states_t, training=False)
        idx = tf.stack([tf.range(BATCH_SIZE, dtype=tf.int32), next_actions], axis=1)
        next_q = tf.gather_nd(next_q_target, idx)

        targets = rewards_t + GAMMA * (1.0 - dones_t) * next_q

        with tf.GradientTape() as tape:
            q_values = self.model(states_t, training=True)
            idx2 = tf.stack([tf.range(BATCH_SIZE, dtype=tf.int32), actions_t], axis=1)
            q_sa = tf.gather_nd(q_values, idx2)
            loss = self.loss_fn(targets, q_sa)

        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))

        # Soft update target network
        self._soft_update_target()

    def add_score(self, score):
        self.scores.append(score)

    def delete_scores(self):
        self.scores = []

    def average_score(self, number_of_episodes):
        index = len(self.scores) - number_of_episodes
        return float(np.mean(self.scores[max(0, index):]))

    def display_scores_graphically(self):
        plt.plot(self.scores)
        plt.xlabel("Episode")
        plt.ylabel("Score")
        plt.title("Training score evolution")

    def save_model(self, path="my_model.keras"):
        self.model.save(path)

# %% [markdown]
# ## Auxiliary function

# %%
def print_time(time):
    min = round(time // 60)
    sec = round(time % 60)
    if min > 0:
        print(f"{min} min {sec} seconds")
    else:
        print(f"{sec} seconds")

# %% [markdown]
# ## Environment

# %%
def create_environment(render_mode=None):
    # Create simulated environment
    environment = gym.make("LunarLander-v3", render_mode=render_mode)
    number_of_observations = environment.observation_space.shape[0]
    number_of_actions = environment.action_space.n
    return environment, number_of_observations, number_of_actions

# %% [markdown]
# ## Program for training

# %%
environment, number_of_observations, number_of_actions = create_environment()
agent = DQN(number_of_observations, number_of_actions)

episode = 0
start_time = time.perf_counter()
total_steps = 0
goal_reached = False

def epsilon_by_step(step):
    if step < WARMUP_STEPS:
        return 1.0
    step2 = step - WARMUP_STEPS
    decay = (EPSILON_START - EPSILON_END) / EPSILON_DECAY_STEPS
    return max(EPSILON_END, EPSILON_START - decay * step2)

def evaluate_greedy(agent, env, n_episodes=10):
    scores = []
    for i in range(n_episodes):
        s, _ = env.reset()  # sin seed fijo
        done = False
        total = 0.0
        while not done:
            a = agent.select_greedy_policy(s)
            s, r, terminated, truncated, _ = env.step(a)
            done = terminated or truncated
            total += r
        scores.append(total)
    return float(np.mean(scores))



while (episode < MAX_EPISODES_FOR_TRAINING) and not(goal_reached):
    episode += 1
    score = 0.0
    state, info = environment.reset(seed=SEED + episode)
    done = False

    while not done:
        exploration_rate = epsilon_by_step(total_steps)
        action = agent.select(state, exploration_rate)

        state_next, reward, terminated, truncated, info = environment.step(action)
        done = terminated or truncated

        done_for_target = terminated

        total_steps += 1

        agent.remember(state, action, reward, state_next, done_for_target)
        score += reward

        if (total_steps >= WARMUP_STEPS) and (total_steps % TRAIN_EVERY == 0):
            agent.learn()

        state = state_next

    agent.add_score(score)
    average_score = agent.average_score(EPISODES_TO_CHECK_TRAINING_GOAL)

    print("Episode {0:>4}: ".format(episode), end='')
    print("score {0:>7} ".format(round(score, 2)), end='')
    print("(epsilon: %.3f, " % epsilon_by_step(total_steps), end='')
    print("avg(last {0}): {1:>6}, ".format(EPISODES_TO_CHECK_TRAINING_GOAL, round(average_score, 2)), end='')
    print("buffer: " + str(agent.memory.current_size) + ", steps: " + str(total_steps) + ")")


    if episode % 25 == 0:
        greedy_mean = evaluate_greedy(agent, environment, n_episodes=10)
        print(f"   >> Greedy eval (10 eps): {greedy_mean:.2f}")

        if greedy_mean > getattr(agent, "best_greedy", -1e9):
            agent.best_greedy = greedy_mean
            agent.model.save("best_model.keras")

        # criterio de parada REAL (el que importa para la práctica)
        if greedy_mean >= TRAINING_GOAL:
            print("✅ Stop: greedy_mean >= 200")
            goal_reached = True


    if (episode >= EPISODES_TO_CHECK_TRAINING_GOAL) and (average_score >= TRAINING_GOAL):
        goal_reached = True

print("Time for training: ", end='')
print_time(time.perf_counter() - start_time)
print("Total steps: ", total_steps)
print("Score (average last episodes):", round(average_score, 2))
print("Score (max):", round(max(agent.scores), 2))

agent.display_scores_graphically()
agent.model.save("last_model.keras")
# Out:
# Episode    1: score -197.62 (epsilon: 1.000, avg(last 50): -197.62, buffer: 81, steps: 81)
# Episode    2: score -175.13 (epsilon: 1.000, avg(last 50): -186.37, buffer: 192, steps: 192)
# Episode    3: score -127.37 (epsilon: 1.000, avg(last 50): -166.71, buffer: 272, steps: 272)
# Episode    4: score  -60.63 (epsilon: 1.000, avg(last 50): -140.19, buffer: 338, steps: 338)
# Episode    5: score -393.71 (epsilon: 1.000, avg(last 50): -190.89, buffer: 465, steps: 465)
# Episode    6: score -195.62 (epsilon: 1.000, avg(last 50): -191.68, buffer: 541, steps: 541)
# Episode    7: score -315.52 (epsilon: 1.000, avg(last 50): -209.37, buffer: 654, steps: 654)
# Episode    8: score -108.86 (epsilon: 1.000, avg(last 50): -196.81, buffer: 718, steps: 718)
# Episode    9: score -201.87 (epsilon: 1.000, avg(last 50): -197.37, buffer: 839, steps: 839)
# Episode   10: score -118.69 (epsilon: 1.000, avg(last 50): -189.5, buffer: 901, steps: 901)
# Episode   11: score -105.41 (epsilon: 1.000, avg(last 50): -181.86, buffer: 1008, steps: 1008)
# Episode   12: score -135.68 (epsilon: 1.000, avg(last 50): -178.01, buffer: 1079, steps: 1079)
# Episode   13: score -229.99 (epsilon: 1.000, avg(last 50): -182.01, buffer: 1163, steps: 1163)
# Episode   14: score -207.68 (epsilon: 1.000, avg(last 50): -183.84, buffer: 1222, steps: 1222)
# Episode   15: score -451.96 (epsilon: 1.000, avg(last 50): -201.72, buffer: 1304, steps: 1304)
# Episode   16: score -144.75 (epsilon: 1.000, avg(last 50): -198.16, buffer: 1382, steps: 1382)
# Episode   17: score -127.73 (epsilon: 1.000, avg(last 50): -194.01, buffer: 1470, steps: 1470)
# Episode   18: score -143.82 (epsilon: 1.000, avg(last 50): -191.22, buffer: 1601, steps: 1601)
# Episode   19: score -275.81 (epsilon: 1.000, avg(last 50): -195.68, buffer: 1708, steps: 1708)
# Episode   20: score  -13.51 (epsilon: 1.000, avg(last 50): -186.57, buffer: 1794, steps: 1794)
# Episode   21: score -174.55 (epsilon: 1.000, avg(last 50): -186.0, buffer: 1877, steps: 1877)
# Episode   22: score -133.27 (epsilon: 1.000, avg(last 50): -183.6, buffer: 1935, steps: 1935)
# Episode   23: score -133.15 (epsilon: 1.000, avg(last 50): -181.41, buffer: 2026, steps: 2026)
# Episode   24: score -261.33 (epsilon: 1.000, avg(last 50): -184.74, buffer: 2131, steps: 2131)
# Episode   25: score -199.44 (epsilon: 1.000, avg(last 50): -185.32, buffer: 2260, steps: 2260)
#    >> Greedy eval (10 eps): -523.66
# Episode   26: score -433.82 (epsilon: 1.000, avg(last 50): -194.88, buffer: 2348, steps: 2348)
# Episode   27: score -287.15 (epsilon: 1.000, avg(last 50): -198.3, buffer: 2441, steps: 2441)
# Episode   28: score  -84.07 (epsilon: 1.000, avg(last 50): -194.22, buffer: 2510, steps: 2510)
# Episode   29: score   -7.45 (epsilon: 1.000, avg(last 50): -187.78, buffer: 2615, steps: 2615)
# Episode   30: score  -99.39 (epsilon: 1.000, avg(last 50): -184.83, buffer: 2705, steps: 2705)
# Episode   31: score -115.65 (epsilon: 1.000, avg(last 50): -182.6, buffer: 2819, steps: 2819)
# Episode   32: score -109.79 (epsilon: 1.000, avg(last 50): -180.33, buffer: 2934, steps: 2934)
# Episode   33: score  -217.5 (epsilon: 1.000, avg(last 50): -181.45, buffer: 3005, steps: 3005)
# Episode   34: score  -96.58 (epsilon: 1.000, avg(last 50): -178.96, buffer: 3083, steps: 3083)
# Episode   35: score  -121.3 (epsilon: 1.000, avg(last 50): -177.31, buffer: 3170, steps: 3170)
# Episode   36: score  -296.9 (epsilon: 1.000, avg(last 50): -180.63, buffer: 3295, steps: 3295)
# Episode   37: score -103.73 (epsilon: 1.000, avg(last 50): -178.55, buffer: 3351, steps: 3351)
# Episode   38: score -120.18 (epsilon: 1.000, avg(last 50): -177.02, buffer: 3421, steps: 3421)
# Episode   39: score -347.76 (epsilon: 1.000, avg(last 50): -181.39, buffer: 3534, steps: 3534)
# Episode   40: score -146.71 (epsilon: 1.000, avg(last 50): -180.53, buffer: 3589, steps: 3589)
# Episode   41: score -111.64 (epsilon: 1.000, avg(last 50): -178.85, buffer: 3675, steps: 3675)
# Episode   42: score -107.08 (epsilon: 1.000, avg(last 50): -177.14, buffer: 3750, steps: 3750)
# Episode   43: score -443.19 (epsilon: 1.000, avg(last 50): -183.33, buffer: 3835, steps: 3835)
# Episode   44: score -122.14 (epsilon: 1.000, avg(last 50): -181.94, buffer: 3914, steps: 3914)
# Episode   45: score -103.04 (epsilon: 1.000, avg(last 50): -180.18, buffer: 3974, steps: 3974)
# Episode   46: score -130.41 (epsilon: 1.000, avg(last 50): -179.1, buffer: 4048, steps: 4048)
# Episode   47: score -238.75 (epsilon: 1.000, avg(last 50): -180.37, buffer: 4135, steps: 4135)
# Episode   48: score  -111.0 (epsilon: 1.000, avg(last 50): -178.92, buffer: 4253, steps: 4253)
# Episode   49: score  -92.06 (epsilon: 1.000, avg(last 50): -177.15, buffer: 4351, steps: 4351)
# Episode   50: score  -88.08 (epsilon: 1.000, avg(last 50): -175.37, buffer: 4435, steps: 4435)
#    >> Greedy eval (10 eps): -646.49
# Episode   51: score -227.68 (epsilon: 1.000, avg(last 50): -175.97, buffer: 4535, steps: 4535)
# Episode   52: score  -29.62 (epsilon: 1.000, avg(last 50): -173.06, buffer: 4618, steps: 4618)
# Episode   53: score -293.99 (epsilon: 1.000, avg(last 50): -176.39, buffer: 4732, steps: 4732)
# Episode   54: score -353.73 (epsilon: 1.000, avg(last 50): -182.26, buffer: 4809, steps: 4809)
# Episode   55: score -111.32 (epsilon: 1.000, avg(last 50): -176.61, buffer: 4919, steps: 4919)
# Episode   56: score -211.78 (epsilon: 1.000, avg(last 50): -176.93, buffer: 5026, steps: 5026)
# Episode   57: score -231.09 (epsilon: 1.000, avg(last 50): -175.24, buffer: 5119, steps: 5119)
# Episode   58: score -270.35 (epsilon: 1.000, avg(last 50): -178.47, buffer: 5215, steps: 5215)
# Episode   59: score   -99.7 (epsilon: 1.000, avg(last 50): -176.43, buffer: 5271, steps: 5271)
# Episode   60: score  -131.0 (epsilon: 1.000, avg(last 50): -176.68, buffer: 5366, steps: 5366)
# Episode   61: score -115.72 (epsilon: 1.000, avg(last 50): -176.88, buffer: 5478, steps: 5478)
# Episode   62: score -119.72 (epsilon: 1.000, avg(last 50): -176.56, buffer: 5573, steps: 5573)
# Episode   63: score -117.82 (epsilon: 1.000, avg(last 50): -174.32, buffer: 5645, steps: 5645)
# Episode   64: score -153.07 (epsilon: 1.000, avg(last 50): -173.23, buffer: 5711, steps: 5711)
# Episode   65: score  -100.9 (epsilon: 1.000, avg(last 50): -166.21, buffer: 5817, steps: 5817)
# Episode   66: score  -51.43 (epsilon: 1.000, avg(last 50): -164.34, buffer: 5883, steps: 5883)
# Episode   67: score -123.41 (epsilon: 1.000, avg(last 50): -164.25, buffer: 5951, steps: 5951)
# Episode   68: score -457.85 (epsilon: 1.000, avg(last 50): -170.53, buffer: 6044, steps: 6044)
# Episode   69: score -141.62 (epsilon: 1.000, avg(last 50): -167.85, buffer: 6130, steps: 6130)
# Episode   70: score -494.09 (epsilon: 1.000, avg(last 50): -177.46, buffer: 6214, steps: 6214)
# Episode   71: score -100.61 (epsilon: 1.000, avg(last 50): -175.98, buffer: 6287, steps: 6287)
# Episode   72: score  -97.36 (epsilon: 1.000, avg(last 50): -175.26, buffer: 6357, steps: 6357)
# Episode   73: score  -93.03 (epsilon: 1.000, avg(last 50): -174.46, buffer: 6430, steps: 6430)
# Episode   74: score -224.45 (epsilon: 1.000, avg(last 50): -173.72, buffer: 6534, steps: 6534)
# Episode   75: score  -273.9 (epsilon: 1.000, avg(last 50): -175.21, buffer: 6633, steps: 6633)
#    >> Greedy eval (10 eps): -587.78
# Episode   76: score -212.84 (epsilon: 1.000, avg(last 50): -170.79, buffer: 6716, steps: 6716)
# Episode   77: score -142.13 (epsilon: 1.000, avg(last 50): -167.89, buffer: 6799, steps: 6799)
# Episode   78: score -197.93 (epsilon: 1.000, avg(last 50): -170.17, buffer: 6872, steps: 6872)
# Episode   79: score -247.85 (epsilon: 1.000, avg(last 50): -174.98, buffer: 6962, steps: 6962)
# Episode   80: score -131.02 (epsilon: 1.000, avg(last 50): -175.61, buffer: 7029, steps: 7029)
# Episode   81: score    4.37 (epsilon: 1.000, avg(last 50): -173.21, buffer: 7108, steps: 7108)
# Episode   82: score -180.89 (epsilon: 1.000, avg(last 50): -174.63, buffer: 7185, steps: 7185)
# Episode   83: score -261.96 (epsilon: 1.000, avg(last 50): -175.52, buffer: 7293, steps: 7293)
# Episode   84: score -102.54 (epsilon: 1.000, avg(last 50): -175.64, buffer: 7379, steps: 7379)
# Episode   85: score -197.04 (epsilon: 1.000, avg(last 50): -177.16, buffer: 7468, steps: 7468)
# Episode   86: score -311.18 (epsilon: 1.000, avg(last 50): -177.44, buffer: 7576, steps: 7576)
# Episode   87: score -238.39 (epsilon: 1.000, avg(last 50): -180.13, buffer: 7662, steps: 7662)
# Episode   88: score -113.38 (epsilon: 1.000, avg(last 50): -180.0, buffer: 7725, steps: 7725)
# Episode   89: score  -79.39 (epsilon: 1.000, avg(last 50): -174.63, buffer: 7789, steps: 7789)
# Episode   90: score -433.24 (epsilon: 1.000, avg(last 50): -180.36, buffer: 7897, steps: 7897)
# Episode   91: score -130.97 (epsilon: 1.000, avg(last 50): -180.75, buffer: 7991, steps: 7991)
# Episode   92: score -122.34 (epsilon: 1.000, avg(last 50): -181.05, buffer: 8072, steps: 8072)
# Episode   93: score -290.46 (epsilon: 1.000, avg(last 50): -178.0, buffer: 8177, steps: 8177)
# Episode   94: score -130.45 (epsilon: 1.000, avg(last 50): -178.16, buffer: 8261, steps: 8261)
# Episode   95: score   -83.2 (epsilon: 1.000, avg(last 50): -177.77, buffer: 8364, steps: 8364)
# Episode   96: score  -29.05 (epsilon: 1.000, avg(last 50): -175.74, buffer: 8442, steps: 8442)
# Episode   97: score  -269.0 (epsilon: 1.000, avg(last 50): -176.35, buffer: 8567, steps: 8567)
# Episode   98: score -248.26 (epsilon: 1.000, avg(last 50): -179.09, buffer: 8651, steps: 8651)
# Episode   99: score -416.28 (epsilon: 1.000, avg(last 50): -185.57, buffer: 8749, steps: 8749)
# Episode  100: score -277.79 (epsilon: 1.000, avg(last 50): -189.37, buffer: 8855, steps: 8855)
#    >> Greedy eval (10 eps): -450.26
# Episode  101: score  -204.0 (epsilon: 1.000, avg(last 50): -188.9, buffer: 8944, steps: 8944)
# Episode  102: score -158.28 (epsilon: 1.000, avg(last 50): -191.47, buffer: 9014, steps: 9014)
# Episode  103: score -337.93 (epsilon: 1.000, avg(last 50): -192.35, buffer: 9121, steps: 9121)
# Episode  104: score -187.34 (epsilon: 1.000, avg(last 50): -189.02, buffer: 9202, steps: 9202)
# Episode  105: score   48.49 (epsilon: 1.000, avg(last 50): -185.82, buffer: 9273, steps: 9273)
# Episode  106: score -153.27 (epsilon: 1.000, avg(last 50): -184.65, buffer: 9344, steps: 9344)
# Episode  107: score -339.92 (epsilon: 1.000, avg(last 50): -186.83, buffer: 9439, steps: 9439)
# Episode  108: score -270.58 (epsilon: 1.000, avg(last 50): -186.83, buffer: 9543, steps: 9543)
# Episode  109: score -141.93 (epsilon: 1.000, avg(last 50): -187.68, buffer: 9625, steps: 9625)
# Episode  110: score -301.98 (epsilon: 1.000, avg(last 50): -191.1, buffer: 9742, steps: 9742)
# Episode  111: score -171.74 (epsilon: 1.000, avg(last 50): -192.22, buffer: 9852, steps: 9852)
# Episode  112: score -313.35 (epsilon: 1.000, avg(last 50): -196.09, buffer: 9939, steps: 9939)
# Episode  113: score -362.32 (epsilon: 1.000, avg(last 50): -200.98, buffer: 10024, steps: 10024)
# Episode  114: score -173.78 (epsilon: 0.999, avg(last 50): -201.4, buffer: 10143, steps: 10143)
# Episode  115: score -305.66 (epsilon: 0.998, avg(last 50): -205.49, buffer: 10315, steps: 10315)
# Episode  116: score  -54.88 (epsilon: 0.997, avg(last 50): -205.56, buffer: 10388, steps: 10388)
# Episode  117: score -132.15 (epsilon: 0.997, avg(last 50): -205.73, buffer: 10473, steps: 10473)
# Episode  118: score -102.55 (epsilon: 0.996, avg(last 50): -198.63, buffer: 10566, steps: 10566)
# Episode  119: score -348.57 (epsilon: 0.996, avg(last 50): -202.77, buffer: 10657, steps: 10657)
# Episode  120: score -372.41 (epsilon: 0.995, avg(last 50): -200.33, buffer: 10776, steps: 10776)
# Episode 1034: score   -4.02 (epsilon: 0.020, avg(last 50): -19.19, buffer: 163045, steps: 163045)
# Episode 1035: score  -73.09 (epsilon: 0.020, avg(last 50): -19.55, buffer: 164045, steps: 164045)
# Episode 1036: score   -7.11 (epsilon: 0.020, avg(last 50): -20.06, buffer: 165045, steps: 165045)
# Episode 1037: score  -22.68 (epsilon: 0.020, avg(last 50): -19.76, buffer: 166045, steps: 166045)
# Episode 1038: score   28.31 (epsilon: 0.020, avg(last 50): -18.15, buffer: 167045, steps: 167045)
# Episode 1039: score  -24.93 (epsilon: 0.020, avg(last 50): -17.76, buffer: 168045, steps: 168045)
# Episode 1040: score   -8.64 (epsilon: 0.020, avg(last 50): -18.26, buffer: 169045, steps: 169045)
# Episode 1041: score  -50.45 (epsilon: 0.020, avg(last 50): -18.37, buffer: 170045, steps: 170045)
# Episode 1042: score   -7.03 (epsilon: 0.020, avg(last 50): -17.46, buffer: 171045, steps: 171045)
# Episode 1043: score   -26.8 (epsilon: 0.020, avg(last 50): -16.94, buffer: 172045, steps: 172045)
# Episode 1044: score  -43.03 (epsilon: 0.020, avg(last 50): -17.16, buffer: 173045, steps: 173045)
# Episode 1045: score     5.8 (epsilon: 0.020, avg(last 50): -16.93, buffer: 174045, steps: 174045)
# Episode 1046: score  -36.71 (epsilon: 0.020, avg(last 50): -17.32, buffer: 175045, steps: 175045)
# Episode 1047: score   27.79 (epsilon: 0.020, avg(last 50): -16.47, buffer: 176045, steps: 176045)
# Episode 1048: score  -62.63 (epsilon: 0.020, avg(last 50): -17.77, buffer: 177045, steps: 177045)
# Episode 1049: score  -29.05 (epsilon: 0.020, avg(last 50): -18.03, buffer: 178045, steps: 178045)
# Episode 1050: score  -18.18 (epsilon: 0.020, avg(last 50): -18.23, buffer: 179045, steps: 179045)
#    >> Greedy eval (10 eps): -17.06
# Episode 1051: score  -32.98 (epsilon: 0.020, avg(last 50): -18.07, buffer: 180045, steps: 180045)
# Episode 1052: score    7.77 (epsilon: 0.020, avg(last 50): -16.91, buffer: 181045, steps: 181045)
# Episode 1053: score    -5.6 (epsilon: 0.020, avg(last 50): -16.83, buffer: 182045, steps: 182045)
# Episode 1054: score   -9.01 (epsilon: 0.020, avg(last 50): -16.79, buffer: 183045, steps: 183045)
# Episode 1055: score   -4.26 (epsilon: 0.020, avg(last 50): -17.19, buffer: 184045, steps: 184045)
# Episode 1056: score   -3.65 (epsilon: 0.020, avg(last 50): -17.52, buffer: 185045, steps: 185045)
# Episode 1057: score  -21.69 (epsilon: 0.020, avg(last 50): -17.94, buffer: 186045, steps: 186045)
# Episode 1058: score   27.11 (epsilon: 0.020, avg(last 50): -17.18, buffer: 187045, steps: 187045)
# Episode 1059: score   -4.76 (epsilon: 0.020, avg(last 50): -17.91, buffer: 188045, steps: 188045)
# Episode 1060: score   -42.7 (epsilon: 0.020, avg(last 50): -17.71, buffer: 189045, steps: 189045)
# Episode 1061: score    0.72 (epsilon: 0.020, avg(last 50): -16.56, buffer: 190045, steps: 190045)
# Episode 1062: score  -75.04 (epsilon: 0.020, avg(last 50): -17.39, buffer: 191045, steps: 191045)
# Episode 1063: score  -18.32 (epsilon: 0.020, avg(last 50): -17.53, buffer: 192045, steps: 192045)
# Episode 1064: score  -20.91 (epsilon: 0.020, avg(last 50): -17.84, buffer: 193045, steps: 193045)
# Episode 1065: score -215.29 (epsilon: 0.020, avg(last 50): -20.34, buffer: 193916, steps: 193916)
# Episode 1066: score -179.73 (epsilon: 0.020, avg(last 50): -23.54, buffer: 194729, steps: 194729)
# Episode 1067: score -218.11 (epsilon: 0.020, avg(last 50): -27.89, buffer: 195572, steps: 195572)
# Episode 1068: score -184.26 (epsilon: 0.020, avg(last 50): -31.18, buffer: 196178, steps: 196178)
# Episode 1069: score  -61.61 (epsilon: 0.020, avg(last 50): -31.82, buffer: 197178, steps: 197178)
# Episode 1070: score   30.15 (epsilon: 0.020, avg(last 50): -30.96, buffer: 198178, steps: 198178)
# Episode 1071: score  111.68 (epsilon: 0.020, avg(last 50): -27.57, buffer: 198796, steps: 198796)
# Episode 1072: score  -75.24 (epsilon: 0.020, avg(last 50): -28.84, buffer: 199796, steps: 199796)
# Episode 1073: score -138.86 (epsilon: 0.020, avg(last 50): -31.22, buffer: 200000, steps: 200434)
# Episode 1074: score  -56.56 (epsilon: 0.020, avg(last 50): -31.97, buffer: 200000, steps: 201434)
# Episode 1075: score  -151.1 (epsilon: 0.020, avg(last 50): -34.63, buffer: 200000, steps: 202101)
#    >> Greedy eval (10 eps): -96.95
# Episode 1076: score -186.93 (epsilon: 0.020, avg(last 50): -38.25, buffer: 200000, steps: 202944)
# Episode 1077: score   -6.89 (epsilon: 0.020, avg(last 50): -37.88, buffer: 200000, steps: 203944)
# Episode 1078: score -192.18 (epsilon: 0.020, avg(last 50): -42.01, buffer: 200000, steps: 204631)
# Episode 1079: score  -10.14 (epsilon: 0.020, avg(last 50): -42.67, buffer: 200000, steps: 205631)
# Episode 1080: score  -41.59 (epsilon: 0.020, avg(last 50): -43.56, buffer: 200000, steps: 206631)
# Episode 1081: score  -87.76 (epsilon: 0.020, avg(last 50): -45.08, buffer: 200000, steps: 207631)
# Episode 1082: score -143.11 (epsilon: 0.020, avg(last 50): -47.51, buffer: 200000, steps: 208273)
# Episode 1083: score  -41.79 (epsilon: 0.020, avg(last 50):  -48.1, buffer: 200000, steps: 209273)
# Episode 1084: score  -28.05 (epsilon: 0.020, avg(last 50): -48.58, buffer: 200000, steps: 210273)
# Episode 1085: score  -17.76 (epsilon: 0.020, avg(last 50): -47.48, buffer: 200000, steps: 211273)
# Episode 1086: score -222.12 (epsilon: 0.020, avg(last 50): -51.78, buffer: 200000, steps: 212080)
# Episode 1087: score -136.72 (epsilon: 0.020, avg(last 50): -54.06, buffer: 200000, steps: 212725)
# Episode 1088: score -126.43 (epsilon: 0.020, avg(last 50): -57.15, buffer: 200000, steps: 213210)
# Episode 1089: score  -64.98 (epsilon: 0.020, avg(last 50): -57.95, buffer: 200000, steps: 214210)
# Episode 1090: score -240.75 (epsilon: 0.020, avg(last 50): -62.59, buffer: 200000, steps: 215098)
# Episode 1091: score  -22.69 (epsilon: 0.020, avg(last 50): -62.04, buffer: 200000, steps: 216098)
# Episode 1092: score -104.12 (epsilon: 0.020, avg(last 50): -63.98, buffer: 200000, steps: 217098)
# Episode 1093: score -147.23 (epsilon: 0.020, avg(last 50): -66.39, buffer: 200000, steps: 217532)
# Episode 1094: score  178.58 (epsilon: 0.020, avg(last 50): -61.96, buffer: 200000, steps: 218054)
# Episode 1095: score  -61.16 (epsilon: 0.020, avg(last 50):  -63.3, buffer: 200000, steps: 219054)
# Episode 1096: score  -74.05 (epsilon: 0.020, avg(last 50): -64.04, buffer: 200000, steps: 220054)
# Episode 1097: score  -87.01 (epsilon: 0.020, avg(last 50): -66.34, buffer: 200000, steps: 220430)
# Episode 1098: score  -52.81 (epsilon: 0.020, avg(last 50): -66.14, buffer: 200000, steps: 221430)
# Episode 1099: score   191.0 (epsilon: 0.020, avg(last 50): -61.74, buffer: 200000, steps: 221952)
# Episode 1100: score  -10.66 (epsilon: 0.020, avg(last 50): -61.59, buffer: 200000, steps: 222952)
#    >> Greedy eval (10 eps): -64.40
# Episode 1101: score    4.29 (epsilon: 0.020, avg(last 50): -60.85, buffer: 200000, steps: 223952)
# Episode 1102: score  168.52 (epsilon: 0.020, avg(last 50): -57.63, buffer: 200000, steps: 224925)
# Episode 1103: score   -61.0 (epsilon: 0.020, avg(last 50): -58.74, buffer: 200000, steps: 225925)
# Episode 1104: score  107.12 (epsilon: 0.020, avg(last 50): -56.42, buffer: 200000, steps: 226925)
# Episode 1105: score   81.08 (epsilon: 0.020, avg(last 50): -54.71, buffer: 200000, steps: 227925)
# Episode 1106: score  168.08 (epsilon: 0.020, avg(last 50): -51.28, buffer: 200000, steps: 228800)
# Episode 1107: score  268.58 (epsilon: 0.020, avg(last 50): -45.47, buffer: 200000, steps: 229100)
# Episode 1108: score   50.26 (epsilon: 0.020, avg(last 50): -45.01, buffer: 200000, steps: 230100)
# Episode 1109: score  176.72 (epsilon: 0.020, avg(last 50): -41.38, buffer: 200000, steps: 230790)
# Episode 1110: score  119.08 (epsilon: 0.020, avg(last 50): -38.14, buffer: 200000, steps: 231751)
# Episode 1111: score  129.97 (epsilon: 0.020, avg(last 50): -35.56, buffer: 200000, steps: 232727)
# Episode 1112: score  257.64 (epsilon: 0.020, avg(last 50):  -28.9, buffer: 200000, steps: 233087)
# Episode 1113: score  -31.22 (epsilon: 0.020, avg(last 50): -29.16, buffer: 200000, steps: 234087)
# Episode 1114: score  193.95 (epsilon: 0.020, avg(last 50): -24.86, buffer: 200000, steps: 234990)
# Episode 1115: score  -19.82 (epsilon: 0.020, avg(last 50): -20.96, buffer: 200000, steps: 235990)
# Episode 1116: score  -34.92 (epsilon: 0.020, avg(last 50): -18.06, buffer: 200000, steps: 236990)
# Episode 1117: score  -15.94 (epsilon: 0.020, avg(last 50): -14.02, buffer: 200000, steps: 237990)
# Episode 1118: score   -56.1 (epsilon: 0.020, avg(last 50): -11.45, buffer: 200000, steps: 238990)
# Episode 1119: score  -42.65 (epsilon: 0.020, avg(last 50): -11.07, buffer: 200000, steps: 239990)
# Episode 1120: score   33.78 (epsilon: 0.020, avg(last 50):  -11.0, buffer: 200000, steps: 240990)
# Episode 1121: score  280.47 (epsilon: 0.020, avg(last 50):  -7.62, buffer: 200000, steps: 241268)
# Episode 1122: score    4.18 (epsilon: 0.020, avg(last 50):  -6.04, buffer: 200000, steps: 242268)
# Episode 1123: score   47.98 (epsilon: 0.020, avg(last 50):   -2.3, buffer: 200000, steps: 243268)
# Episode 1124: score  219.91 (epsilon: 0.020, avg(last 50):   3.23, buffer: 200000, steps: 244053)
# Episode 1125: score  -21.52 (epsilon: 0.020, avg(last 50):   5.82, buffer: 200000, steps: 245053)
#    >> Greedy eval (10 eps): 23.12
# Episode 1126: score  236.06 (epsilon: 0.020, avg(last 50):  14.28, buffer: 200000, steps: 245383)
# Episode 1127: score   -6.72 (epsilon: 0.020, avg(last 50):  14.28, buffer: 200000, steps: 246383)
# Episode 1128: score  161.18 (epsilon: 0.020, avg(last 50):  21.35, buffer: 200000, steps: 246933)
# Episode 1129: score  205.94 (epsilon: 0.020, avg(last 50):  25.67, buffer: 200000, steps: 247775)
# Episode 1130: score  -33.07 (epsilon: 0.020, avg(last 50):  25.84, buffer: 200000, steps: 248775)
# Episode 1131: score  272.85 (epsilon: 0.020, avg(last 50):  33.06, buffer: 200000, steps: 249016)
# Episode 1132: score     0.7 (epsilon: 0.020, avg(last 50):  35.93, buffer: 200000, steps: 250016)
# Episode 1133: score  238.96 (epsilon: 0.020, avg(last 50):  41.55, buffer: 200000, steps: 250267)
# Episode 1134: score  227.66 (epsilon: 0.020, avg(last 50):  46.66, buffer: 200000, steps: 250700)
# Episode 1135: score  181.47 (epsilon: 0.020, avg(last 50):  50.65, buffer: 200000, steps: 251493)
# Episode 1136: score    -3.0 (epsilon: 0.020, avg(last 50):  55.03, buffer: 200000, steps: 252493)
# Episode 1137: score   15.84 (epsilon: 0.020, avg(last 50):  58.08, buffer: 200000, steps: 253493)
# Episode 1138: score    1.11 (epsilon: 0.020, avg(last 50):  60.63, buffer: 200000, steps: 254493)
# Episode 1139: score  -32.74 (epsilon: 0.020, avg(last 50):  61.28, buffer: 200000, steps: 255493)
# Episode 1140: score  150.26 (epsilon: 0.020, avg(last 50):   69.1, buffer: 200000, steps: 256399)
# Episode 1141: score   263.1 (epsilon: 0.020, avg(last 50):  74.81, buffer: 200000, steps: 256643)
# Episode 1142: score  217.05 (epsilon: 0.020, avg(last 50):  81.23, buffer: 200000, steps: 257195)
# Episode 1143: score  182.21 (epsilon: 0.020, avg(last 50):  87.82, buffer: 200000, steps: 257986)
# Episode 1144: score   36.71 (epsilon: 0.020, avg(last 50):  84.99, buffer: 200000, steps: 258986)
# Episode 1145: score    3.76 (epsilon: 0.020, avg(last 50):  86.28, buffer: 200000, steps: 259986)
# Episode 1146: score  238.48 (epsilon: 0.020, avg(last 50):  92.54, buffer: 200000, steps: 260349)
# Episode 1147: score  -36.34 (epsilon: 0.020, avg(last 50):  93.55, buffer: 200000, steps: 261349)
# Episode 1148: score   236.2 (epsilon: 0.020, avg(last 50):  99.33, buffer: 200000, steps: 261820)
# Episode 1149: score  281.09 (epsilon: 0.020, avg(last 50): 101.13, buffer: 200000, steps: 262029)
# Episode 1150: score   38.01 (epsilon: 0.020, avg(last 50):  102.1, buffer: 200000, steps: 263029)
#    >> Greedy eval (10 eps): 129.01
# Episode 1151: score   18.97 (epsilon: 0.020, avg(last 50):  102.4, buffer: 200000, steps: 264029)
# Episode 1152: score   194.7 (epsilon: 0.020, avg(last 50): 102.92, buffer: 200000, steps: 264629)
# Episode 1153: score  289.14 (epsilon: 0.020, avg(last 50): 109.92, buffer: 200000, steps: 264831)
# Episode 1154: score  237.24 (epsilon: 0.020, avg(last 50): 112.53, buffer: 200000, steps: 265225)
# Episode 1155: score  189.69 (epsilon: 0.020, avg(last 50):  114.7, buffer: 200000, steps: 266069)
# Episode 1156: score  238.38 (epsilon: 0.020, avg(last 50): 116.11, buffer: 200000, steps: 266705)
# Episode 1157: score  212.84 (epsilon: 0.020, avg(last 50): 114.99, buffer: 200000, steps: 267609)
# Episode 1158: score  180.38 (epsilon: 0.020, avg(last 50): 117.59, buffer: 200000, steps: 268529)
# Episode 1159: score  240.98 (epsilon: 0.020, avg(last 50): 118.88, buffer: 200000, steps: 269017)
# Episode 1160: score  235.73 (epsilon: 0.020, avg(last 50): 121.21, buffer: 200000, steps: 269378)
# Episode 1161: score   188.4 (epsilon: 0.020, avg(last 50): 122.38, buffer: 200000, steps: 270021)
# Episode 1162: score  201.05 (epsilon: 0.020, avg(last 50): 121.25, buffer: 200000, steps: 271001)
# Episode 1163: score  245.84 (epsilon: 0.020, avg(last 50): 126.79, buffer: 200000, steps: 271488)
# Episode 1164: score  236.59 (epsilon: 0.020, avg(last 50): 127.64, buffer: 200000, steps: 271891)
# Episode 1165: score   263.8 (epsilon: 0.020, avg(last 50): 133.31, buffer: 200000, steps: 272079)
# Episode 1166: score  205.63 (epsilon: 0.020, avg(last 50): 138.13, buffer: 200000, steps: 272865)
# Episode 1167: score  228.74 (epsilon: 0.020, avg(last 50): 143.02, buffer: 200000, steps: 273401)
# Episode 1168: score   273.7 (epsilon: 0.020, avg(last 50): 149.61, buffer: 200000, steps: 273763)
# Episode 1169: score  224.86 (epsilon: 0.020, avg(last 50): 154.96, buffer: 200000, steps: 274380)
# Episode 1170: score  254.71 (epsilon: 0.020, avg(last 50): 159.38, buffer: 200000, steps: 274845)
# Episode 1171: score   49.28 (epsilon: 0.020, avg(last 50): 154.76, buffer: 200000, steps: 274951)
# Episode 1172: score  216.98 (epsilon: 0.020, avg(last 50): 159.02, buffer: 200000, steps: 275637)
# Episode 1173: score  278.65 (epsilon: 0.020, avg(last 50): 163.63, buffer: 200000, steps: 275905)
# Episode 1174: score  247.26 (epsilon: 0.020, avg(last 50): 164.18, buffer: 200000, steps: 276393)
# Episode 1175: score  259.33 (epsilon: 0.020, avg(last 50): 169.79, buffer: 200000, steps: 276815)
#    >> Greedy eval (10 eps): 186.45
# Episode 1176: score  237.05 (epsilon: 0.020, avg(last 50): 169.81, buffer: 200000, steps: 277369)
# Episode 1177: score  269.62 (epsilon: 0.020, avg(last 50): 175.34, buffer: 200000, steps: 277545)
# Episode 1178: score  294.42 (epsilon: 0.020, avg(last 50):  178.0, buffer: 200000, steps: 277833)
# Episode 1179: score  268.17 (epsilon: 0.020, avg(last 50): 179.25, buffer: 200000, steps: 278176)
# Episode 1180: score   31.32 (epsilon: 0.020, avg(last 50): 180.54, buffer: 200000, steps: 278379)
# Episode 1181: score    50.1 (epsilon: 0.020, avg(last 50): 176.08, buffer: 200000, steps: 278513)
# Episode 1182: score  239.73 (epsilon: 0.020, avg(last 50): 180.86, buffer: 200000, steps: 278917)
# Episode 1183: score  173.41 (epsilon: 0.020, avg(last 50): 179.55, buffer: 200000, steps: 279833)
# Episode 1184: score  268.03 (epsilon: 0.020, avg(last 50): 180.36, buffer: 200000, steps: 280306)
# Episode 1185: score  243.57 (epsilon: 0.020, avg(last 50):  181.6, buffer: 200000, steps: 280555)
# Episode 1186: score  250.59 (epsilon: 0.020, avg(last 50): 186.67, buffer: 200000, steps: 281176)
# Episode 1187: score  308.54 (epsilon: 0.020, avg(last 50): 192.53, buffer: 200000, steps: 281487)
# Episode 1188: score   266.7 (epsilon: 0.020, avg(last 50): 197.84, buffer: 200000, steps: 281726)
# Episode 1189: score  252.67 (epsilon: 0.020, avg(last 50): 203.55, buffer: 200000, steps: 282003)
# Time for training: 161 min 29 seconds
# Total steps:  282003
# Score (average last episodes): 203.55
# Score (max): 308.54

# %% [markdown]
# ## Testing program

# %%
agent.delete_scores()
episode = 0
start_time = time.perf_counter()
while (episode < EPISODES_TO_EVALUATE_MODEL_PERFORMANCE):
    episode += 1
    score = 0
    state, info = environment.reset()
    end_episode = False
    while not(end_episode):
        # Select an action for the current state
        action = agent.select_greedy_policy(state)

        # Execute the action in the environment
        state_next, reward, terminal_state, truncated, info = environment.step(action)

        score += reward

        # Detect end of episode and print
        if terminal_state or truncated:
            agent.add_score(score)
            print("Episode {0:>3}: ".format(episode), end = '')
            print("score {0:>3} \n".format(round(score)), end = '')
            end_episode = True
        else:
            state = state_next

print("Time for testing: ", end = '')
print_time(time.perf_counter() - start_time)
print("Score (average):", round(np.mean(agent.scores)))
print("Score (max):", round(max(agent.scores)))
# Out:
# Episode   1: score 266
# Episode   2: score 285
# Episode   3: score 262
# Episode   4: score 273
# Episode   5: score 258
# Episode   6: score 270
# Episode   7: score 275
# Episode   8: score 270
# Episode   9: score 221
# Episode  10: score 244
# Episode  11: score 260
# Episode  12: score 275
# Episode  13: score 262
# Episode  14: score 288
# Episode  15: score 301
# Episode  16: score 278
# Episode  17: score 283
# Episode  18: score 251
# Episode  19: score 217
# Episode  20: score 163
# Episode  21: score 243
# Episode  22: score 250
# Episode  23: score 109
# Episode  24: score 272
# Episode  25: score 272
# Episode  26: score 311
# Episode  27: score 237
# Episode  28: score 279
# Episode  29: score 247
# Episode  30: score 125
# Time for testing: 49 seconds
# Score (average): 252
# Score (max): 311
